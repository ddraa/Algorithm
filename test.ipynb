# %%
def isupper(s):
    if ord('A')<=ord(s)<=ord('Z'):
        return True # 대문자
    elif ord('a')<=ord(s)<=ord('z'):
        return False # 소문자

# %%
isupper('B')
# Out:
# True

# %%
isupper('k')
# Out:
# False
